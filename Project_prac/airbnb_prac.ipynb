# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir("E:\\Project_prac")
data=pd.read_csv("airbnb.csv")

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 16 columns):
# id                                4019 non-null int64
# name                              4017 non-null object
# host_id                           4019 non-null int64
# host_name                         4017 non-null object
# neighbourhood_group               4019 non-null object
# neighbourhood                     4019 non-null object
# latitude                          4019 non-null float64
# longitude                         4019 non-null float64
# room_type                         4019 non-null object
# price                             4019 non-null int64
# minimum_nights                    4019 non-null int64
# number_of_reviews                 4019 non-null int64
# last_review                       3679 non-null object
# reviews_per_month                 3679 non-null float64
# calculated_host_listings_count    4019 non-null int64
# ...

# %%
data[data.last_review.isnull()]
# Out:
#            id                                               name   host_id  \
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19       7750                  Huge 2 BR Upper East  Cental Park     17985
# 26       8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36      11452                        Clean and Quiet in Brooklyn      7355
# 38      11943                          Country space in the city     45445
# 193     51438                1 Bedroom in 2 Bdrm Apt- Upper East    236421
# 204     54466                Beautiful Uptown Manhattan apartmnt    253385
# 260     63588                                                LL3    295128
# 265     63913             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM    312288
# 267     64015                       Prime East Village 1 Bedroom    146944
# 276     65556                 Room in S3rd/Bedford, Williamsburg    320422
# ...

# %%
data.describe(include='all')
# Out:
#                   id                              name       host_id  \
# count   4.019000e+03                              4017  4.019000e+03
# unique           NaN                              3990           NaN
# top              NaN  Loft Suite @ The Box House Hotel           NaN
# freq             NaN                                11           NaN
# mean    1.064708e+06                               NaN  4.022870e+06
# std     7.504620e+05                               NaN  3.604295e+06
# min     2.539000e+03                               NaN  2.571000e+03
# 25%     4.072305e+05                               NaN  9.347460e+05
# 50%     8.873550e+05                               NaN  2.886652e+06
# 75%     1.762682e+06                               NaN  6.532810e+06
# max     2.524213e+06                               NaN  1.731875e+07
#
#        host_name neighbourhood_group neighbourhood     latitude    longitude  \
# ...

# %%
data.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  4.019000e+03  4.019000e+03  4019.000000  4019.000000  4019.000000
# mean   1.064708e+06  4.022870e+06    40.728857   -73.961357   177.023638
# std    7.504620e+05  3.604295e+06     0.050603     0.035838   275.053455
# min    2.539000e+03  2.571000e+03    40.508680   -74.239860    10.000000
# 25%    4.072305e+05  9.347460e+05    40.689380   -73.984955    83.000000
# 50%    8.873550e+05  2.886652e+06    40.723470   -73.961120   125.000000
# 75%    1.762682e+06  6.532810e+06    40.761655   -73.945400   195.000000
# max    2.524213e+06  1.731875e+07    40.908040   -73.733230  6500.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     4019.000000        4019.000000        3679.000000
# mean         8.956208          61.379696           0.923843
# std         28.868147          79.530389           1.085022
# min          1.000000           0.000000           0.010000
# ...

# %%
data.plot.scatter(x='price',y='minimum_nights',color='c',title='scatter Price vs Minimun nights')

# %%
data.plot.scatter(x='availability_365',y='price',color='c',title='scatter Price vs availability_365')

# %%
data.plot.scatter(x='number_of_reviews',y='price',color='c',title='scatter Price vs number_of_reviews')

# %%
data.plot.scatter(x='calculated_host_listings_count',y='price',color='b',title='scatter Price vs calculated_host_listings_count')

# %%
data.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.735461  0.029880   0.033758
# host_id                         0.735461  1.000000  0.065190   0.038670
# latitude                        0.029880  0.065190  1.000000   0.160142
# longitude                       0.033758  0.038670  0.160142   1.000000
# price                           0.099066  0.066293  0.021423  -0.165429
# minimum_nights                 -0.022350 -0.011525  0.001971  -0.053556
# number_of_reviews              -0.166135 -0.125707  0.005219   0.065236
# reviews_per_month               0.000029  0.008959  0.013561   0.074634
# calculated_host_listings_count  0.027111 -0.006028  0.013580   0.045455
# availability_365               -0.134429 -0.087677  0.007822   0.130867
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.099066       -0.022350          -0.166135
# ...

# %%
data.plot.scatter(x='host_id',y='price',color='c',title='scatter Price vs host_id')

# %%
data[data['last_review'].isnull()]
# Out:
#            id                                               name   host_id  \
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19       7750                  Huge 2 BR Upper East  Cental Park     17985
# 26       8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36      11452                        Clean and Quiet in Brooklyn      7355
# 38      11943                          Country space in the city     45445
# 193     51438                1 Bedroom in 2 Bdrm Apt- Upper East    236421
# 204     54466                Beautiful Uptown Manhattan apartmnt    253385
# 260     63588                                                LL3    295128
# 265     63913             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM    312288
# 267     64015                       Prime East Village 1 Bedroom    146944
# 276     65556                 Room in S3rd/Bedford, Williamsburg    320422
# ...

# %%
data.price.plot(kind='hist',title='histogram for price',color='r')

# %%
data.availability_365.plot(kind='hist',title='histogram for 365 availability',color='c')

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data.reviews_per_month.plot(kind='hist',title='histogram for reviews for month',color='c')

# %%
data.minimum_nights.plot(kind='hist',title='histogram for the minimum number of nights',color='c')

# %%
data[['price','neighbourhood_group']].boxplot(by='neighbourhood_group')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 16 columns):
# id                                4019 non-null int64
# name                              4017 non-null object
# host_id                           4019 non-null int64
# host_name                         4017 non-null object
# neighbourhood_group               4019 non-null object
# neighbourhood                     4019 non-null object
# latitude                          4019 non-null float64
# longitude                         4019 non-null float64
# room_type                         4019 non-null object
# price                             4019 non-null int64
# minimum_nights                    4019 non-null int64
# number_of_reviews                 4019 non-null int64
# last_review                       3679 non-null object
# reviews_per_month                 3679 non-null float64
# calculated_host_listings_count    4019 non-null int64
# ...

# %%
data[data['reviews_per_month'].isnull()]
# Out:
#            id                                               name   host_id  \
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19       7750                  Huge 2 BR Upper East  Cental Park     17985
# 26       8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36      11452                        Clean and Quiet in Brooklyn      7355
# 38      11943                          Country space in the city     45445
# 193     51438                1 Bedroom in 2 Bdrm Apt- Upper East    236421
# 204     54466                Beautiful Uptown Manhattan apartmnt    253385
# 260     63588                                                LL3    295128
# 265     63913             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM    312288
# 267     64015                       Prime East Village 1 Bedroom    146944
# 276     65556                 Room in S3rd/Bedford, Williamsburg    320422
# ...

# %%
data.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.plot.scatter(x='number_of_reviews',y='reviews_per_month',color='c',title='number of reviews vs reviews per month')

# %%
data.neighbourhood_group.value_counts().plot(kind='bar',color='c',title='count vs neighbourhood_group')

# %%
data.neighbourhood.value_counts().plot(kind='bar',color='c',title='count vs neighbourhood',figsize=(20,10))

# %%
data.room_type.value_counts().plot(kind='bar',color='c',title='count vs room_type')

# %%
pd.crosstab(data.neighbourhood_group,data.room_type).plot(kind='bar',figsize=(12,5))

# %%
sum(data.price.loc[data['room_type']=='Private room'])  #to find the sum of price for the particular room type.
# Out:
# 149025

# %%
sum(data.price[data['room_type']=='Entire home/apt'])
# Out:
# 557030

# %%
sum(data.price[data['room_type']=='Shared room'])
# Out:
# 5403

# %%
sum(data.price[data.room_type=='Shared room'])
# Out:
# 5403

# %%
data.loc[5:10,['name','host_name']]  #to select the particular columns using the loc
# Out:
#                                          name  host_name
# 5   Large Cozy 1 BR Apartment In Midtown East      Chris
# 6                             BlissArtsSpace!      Garon
# 7            Large Furnished Room Near B'way    Shunichi
# 8          Cozy Clean Guest Room - Family Apt  MaryEllen
# 9          Cute & Cozy Lower East Side 1 bdrm        Ben
# 10           Beautiful 1br on Upper West Side       Lena

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 16 columns):
# id                                4019 non-null int64
# name                              4017 non-null object
# host_id                           4019 non-null int64
# host_name                         4017 non-null object
# neighbourhood_group               4019 non-null object
# neighbourhood                     4019 non-null object
# latitude                          4019 non-null float64
# longitude                         4019 non-null float64
# room_type                         4019 non-null object
# price                             4019 non-null int64
# minimum_nights                    4019 non-null int64
# number_of_reviews                 4019 non-null int64
# last_review                       3679 non-null object
# reviews_per_month                 3679 non-null float64
# calculated_host_listings_count    4019 non-null int64
# ...

# %%
data[data.last_review.isnull()]
# Out:
#            id                                               name   host_id  \
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19       7750                  Huge 2 BR Upper East  Cental Park     17985
# 26       8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36      11452                        Clean and Quiet in Brooklyn      7355
# 38      11943                          Country space in the city     45445
# 193     51438                1 Bedroom in 2 Bdrm Apt- Upper East    236421
# 204     54466                Beautiful Uptown Manhattan apartmnt    253385
# 260     63588                                                LL3    295128
# 265     63913             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM    312288
# 267     64015                       Prime East Village 1 Bedroom    146944
# 276     65556                 Room in S3rd/Bedford, Williamsburg    320422
# ...

# %%
data[data.reviews_per_month.isnull()]
# Out:
#            id                                               name   host_id  \
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19       7750                  Huge 2 BR Upper East  Cental Park     17985
# 26       8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36      11452                        Clean and Quiet in Brooklyn      7355
# 38      11943                          Country space in the city     45445
# 193     51438                1 Bedroom in 2 Bdrm Apt- Upper East    236421
# 204     54466                Beautiful Uptown Manhattan apartmnt    253385
# 260     63588                                                LL3    295128
# 265     63913             HOSTING YOUR  SUNNY, SPACIOUS NYC ROOM    312288
# 267     64015                       Prime East Village 1 Bedroom    146944
# 276     65556                 Room in S3rd/Bedford, Williamsburg    320422
# ...

# %%
data.reviews_per_month.mean()
# Out:
# 0.9238434357162278

# %%
data.reviews_per_month.median()
# Out:
# 0.5

# %%
#applying the group and aggregation
data.groupby('room_type').agg({'reviews_per_month':'mean','price':'mean'})
# Out:
#                  reviews_per_month       price
# room_type
# Entire home/apt           0.829184  229.041941
# Private room              1.063736   97.147979
# Shared room               1.195682  101.943396

# %%
data.groupby('room_type').agg({'reviews_per_month':'median','price':'median'})
# Out:
#                  reviews_per_month  price
# room_type
# Entire home/apt               0.42    165
# Private room                  0.63     79
# Shared room                   0.90     65

# %%
#applying the group to the multiple columns and takins the price median
data.groupby(['room_type', 'neighbourhood_group']).price.median()
# Out:
# room_type        neighbourhood_group
# Entire home/apt  Bronx                  105.0
#                  Brooklyn               150.0
#                  Manhattan              190.0
#                  Queens                 110.0
#                  Staten Island          235.5
# Private room     Bronx                   50.0
#                  Brooklyn                75.0
#                  Manhattan               92.5
#                  Queens                  65.0
#                  Staten Island           56.5
# Shared room      Bronx                   32.0
#                  Brooklyn                44.5
#                  Manhattan               80.0
#                  Queens                  65.0
# Name: price, dtype: float64

# %%
data[['price','room_type']].boxplot(by='room_type')

# %%
#on a data frame extract we can fin d the min,max
data[data.room_type=='Entire home/apt'].max()
# Out:
# id                                        2524058
# host_id                                  15145088
# neighbourhood_group                 Staten Island
# neighbourhood                            Woodside
# latitude                                  40.8975
# longitude                                -73.7395
# room_type                         Entire home/apt
# price                                        6500
# minimum_nights                               1000
# number_of_reviews                             467
# reviews_per_month                              10
# calculated_host_listings_count                 52
# availability_365                              365
# dtype: object

# %%
print('skewness for price : {0:.3f}'.format(data.price.skew()))
# Out:
# skewness for price : 12.082

# %%
data_price_log=np.log(data.price)

# %%
data_price_log.skew()
# Out:
# 0.8805437054069548

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
#            id                                               name   host_id  \
# 0        2539                 Clean & quiet apt home by the park      2787
# 1        2595                              Skylit Midtown Castle      2845
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3        3831                    Cozy Entire Floor of Brownstone      4869
# 4        5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 5        5099          Large Cozy 1 BR Apartment In Midtown East      7322
# 6        5121                                    BlissArtsSpace!      7356
# 7        5178                   Large Furnished Room Near B'way       8967
# 8        5203                 Cozy Clean Guest Room - Family Apt      7490
# 9        5238                 Cute & Cozy Lower East Side 1 bdrm      7549
# 10       5295                   Beautiful 1br on Upper West Side      7702
# ...

# %%
data_copy.drop(columns=['host_id','host_name','latitude','longitude','last_review','name','neighbourhood','id'],inplace=True)

# %%
data_copy.describe()
# Out:
#              price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  4019.000000     4019.000000        4019.000000        3679.000000
# mean    177.023638        8.956208          61.379696           0.923843
# std     275.053455       28.868147          79.530389           1.085022
# min      10.000000        1.000000           0.000000           0.010000
# 25%      83.000000        2.000000           7.000000           0.170000
# 50%     125.000000        3.000000          28.000000           0.500000
# 75%     195.000000        5.000000          86.000000           1.310000
# max    6500.000000     1000.000000         607.000000          10.000000
#
#        calculated_host_listings_count  availability_365
# count                     4019.000000       4019.000000
# mean                         2.314257        150.086838
# std                          5.661694        137.698980
# min                          1.000000          0.000000
# ...

# %%
data_copy.reviews_per_month.median()
# Out:
# 0.5

# %%
shared_room=data_copy[data_copy.room_type=='Shared room']

# %%
shared_room.reviews_per_month.median()
# Out:
# 0.9

# %%
entire_home=data_copy[data_copy.room_type=='Entire home/apt']

# %%
entire_home.reviews_per_month.mean()
# Out:
# 0.8291843172600228

# %%
Private_room=data_copy[data_copy.room_type=='Private room']

# %%
Private_room.reviews_per_month.mean()
# Out:
# 1.0637358757062114

# %%
Private_room.reviews_per_month.median()
# Out:
# 0.63

# %%
shared_room.reviews_per_month.isnull().value_counts()
# Out:
# False    44
# True      9
# Name: reviews_per_month, dtype: int64

# %%
#checking the room type and calculating the median of the reviews per month
data_copy[data_copy.room_type=='Shared room'].reviews_per_month.median()
# Out:
# 0.9

# %%
data_copy[data_copy.room_type=='Private room'].reviews_per_month.median()
# Out:
# 0.63

# %%
data_copy[data_copy.room_type=='Entire home/apt'].reviews_per_month.median()
# Out:
# 0.42

# %%
#this will not work
data_copy[data_copy.room_type=='Shared room'].reviews_per_month.fillna(0.9,inplace=True)
# Out:
# E:\anaconda\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
data_copy[data_copy.room_type=='Entire home/apt'].reviews_per_month.fillna(0.42,inplace=True)

# %%
data_copy[data_copy.room_type=='Private room'].reviews_per_month.fillna(0.63,inplace=True)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4019 entries, 0 to 4018
# Data columns (total 8 columns):
# neighbourhood_group               4019 non-null object
# room_type                         4019 non-null object
# price                             4019 non-null int64
# minimum_nights                    4019 non-null int64
# number_of_reviews                 4019 non-null int64
# reviews_per_month                 3679 non-null float64
# calculated_host_listings_count    4019 non-null int64
# availability_365                  4019 non-null int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 251.3+ KB

# %%
data_copy.reviews_per_month.median()
# Out:
# 0.5

# %%
data_copy.reviews_per_month.fillna(0.5,inplace=True)

# %%
data_copy[data_copy.reviews_per_month.isnull()]
# Out:
# Empty DataFrame
# Columns: [neighbourhood_group, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
data_copy.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.010142          -0.103965
# minimum_nights                 -0.010142        1.000000          -0.098091
# number_of_reviews              -0.103965       -0.098091           1.000000
# reviews_per_month              -0.074892       -0.098092           0.907836
# calculated_host_listings_count -0.017536        0.074761          -0.055379
# availability_365               -0.045107        0.075540           0.216651
#
#                                 reviews_per_month  \
# price                                   -0.074892
# minimum_nights                          -0.098092
# number_of_reviews                        0.907836
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.068383
# availability_365                         0.168528
#
#                                 calculated_host_listings_count  \
# ...

# %% [markdown]
# # Handling the outliers

# %%
data_copy['price_log']=np.log(data_copy.price)

# %%
data_copy.price_log.plot(kind='hist',color='c',title='log value of the price')

# %%
data.price.plot(kind='hist',color='r')

# %%
data_copy.reviews_per_month.plot(kind='hist')

# %%
data_copy['reviews_log']=np.log(data_copy.reviews_per_month)

# %%
data_copy.reviews_log.plot(kind='hist',color='c',title='log values of the reviews per month')

# %%
data_copy.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.010142          -0.103965
# minimum_nights                 -0.010142        1.000000          -0.098091
# number_of_reviews              -0.103965       -0.098091           1.000000
# reviews_per_month              -0.074892       -0.098092           0.907836
# calculated_host_listings_count -0.017536        0.074761          -0.055379
# availability_365               -0.045107        0.075540           0.216651
# price_log                       0.693182        0.004553          -0.131604
# reviews_log                    -0.037177       -0.099475           0.745924
#
#                                 reviews_per_month  \
# price                                   -0.074892
# minimum_nights                          -0.098092
# number_of_reviews                        0.907836
# reviews_per_month                        1.000000
# ...

# %%
data_copy[['price_log','room_type']].boxplot(by='room_type')

# %%
data_copy.number_of_reviews.plot(kind='hist',color='blue')

# %%
#+ added to avoid the log(0) and divide by zero
data_copy['number_of_reviews_log']=np.log(data_copy.number_of_reviews+1)

# %%
data_copy.head()
# Out:
#   neighbourhood_group        room_type  price  minimum_nights  \
# 0            Brooklyn     Private room    149               1
# 1           Manhattan  Entire home/apt    225               1
# 2           Manhattan     Private room    150               3
# 3            Brooklyn  Entire home/apt     89               1
# 4           Manhattan  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0               0.50                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365  price_log  reviews_log  number_of_reviews_log
# 0               365   5.003946    -1.560648               2.302585
# ...

# %%
data_copy.number_of_reviews_log.plot(kind='hist',color='c',title='log value of number of reviews')

# %%
data_copy[['number_of_reviews_log','room_type']].boxplot(by='room_type',figsize=(12,5))

# %%
data_copy[['reviews_log','room_type']].boxplot(by='room_type',figsize=(10,5))

# %%
data_copy.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.010142          -0.103965
# minimum_nights                 -0.010142        1.000000          -0.098091
# number_of_reviews              -0.103965       -0.098091           1.000000
# reviews_per_month              -0.074892       -0.098092           0.907836
# calculated_host_listings_count -0.017536        0.074761          -0.055379
# availability_365               -0.045107        0.075540           0.216651
# price_log                       0.693182        0.004553          -0.131604
# reviews_log                    -0.037177       -0.099475           0.745924
# number_of_reviews_log          -0.177637       -0.105644           0.786917
#
#                                 reviews_per_month  \
# price                                   -0.074892
# minimum_nights                          -0.098092
# number_of_reviews                        0.907836
# ...

# %%
data_copy[['neighbourhood_group','price_log']].boxplot(by='neighbourhood_group',figsize=(14,5))

# %%
data_copy[['neighbourhood_group','reviews_log']].boxplot(by='neighbourhood_group')

# %%
data_copy[['neighbourhood_group','number_of_reviews_log']].boxplot(by='neighbourhood_group')

# %%
data_copy.head()
# Out:
#   neighbourhood_group        room_type  price  minimum_nights  \
# 0            Brooklyn     Private room    149               1
# 1           Manhattan  Entire home/apt    225               1
# 2           Manhattan     Private room    150               3
# 3            Brooklyn  Entire home/apt     89               1
# 4           Manhattan  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0               0.50                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365  price_log  reviews_log  number_of_reviews_log
# 0               365   5.003946    -1.560648               2.302585
# ...

# %%
data_copy.availability_365.plot(kind='hist')

# %%
data_copy['availability_365_log']=np.log(data_copy.availability_365+1)

# %%
data_copy.availability_365_log.plot(kind='hist',color='c',title='log value of the availability 365')

# %%
data_copy.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.010142          -0.103965
# minimum_nights                 -0.010142        1.000000          -0.098091
# number_of_reviews              -0.103965       -0.098091           1.000000
# reviews_per_month              -0.074892       -0.098092           0.907836
# calculated_host_listings_count -0.017536        0.074761          -0.055379
# availability_365               -0.045107        0.075540           0.216651
# price_log                       0.693182        0.004553          -0.131604
# reviews_log                    -0.037177       -0.099475           0.745924
# number_of_reviews_log          -0.177637       -0.105644           0.786917
# availability_365_log           -0.083514        0.062695           0.315346
#
#                                 reviews_per_month  \
# price                                   -0.074892
# ...

# %%
data.calculated_host_listings_count.plot(kind='hist')

# %%
# 1 is added to aviod the divid by zero error
data_copy['calculated_host_log']=np.log(data_copy.calculated_host_listings_count+1)

# %%
data_copy.calculated_host_log.plot(kind='hist',color='c',title='log value of the calculated hostings count')

# %%
data_copy.corr()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.010142          -0.103965
# minimum_nights                 -0.010142        1.000000          -0.098091
# number_of_reviews              -0.103965       -0.098091           1.000000
# reviews_per_month              -0.074892       -0.098092           0.907836
# calculated_host_listings_count -0.017536        0.074761          -0.055379
# availability_365               -0.045107        0.075540           0.216651
# price_log                       0.693182        0.004553          -0.131604
# reviews_log                    -0.037177       -0.099475           0.745924
# number_of_reviews_log          -0.177637       -0.105644           0.786917
# availability_365_log           -0.083514        0.062695           0.315346
# calculated_host_log            -0.053822        0.055930           0.029191
#
#                                 reviews_per_month  \
# ...

# %%
np.exp(data_copy.price_log).plot(kind='hist',color='c',title='exponent of the price_log')

# %%
data_copy[['availability_365_log','room_type']].boxplot(by='room_type',figsize=(12,5))

# %%
data_copy[['calculated_host_log','room_type']].boxplot(by='room_type',figsize=(12,5))

# %%
data_copy.head()
# Out:
#   neighbourhood_group        room_type  price  minimum_nights  \
# 0            Brooklyn     Private room    149               1
# 1           Manhattan  Entire home/apt    225               1
# 2           Manhattan     Private room    150               3
# 3            Brooklyn  Entire home/apt     89               1
# 4           Manhattan  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0               0.50                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365  price_log  reviews_log  number_of_reviews_log  \
# 0               365   5.003946    -1.560648               2.302585
# ...

# %%
data_copy.columns
# Out:
# Index(['neighbourhood_group', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'price_log',
#        'reviews_log', 'number_of_reviews_log', 'availability_365_log',
#        'calculated_host_log'],
#       dtype='object')

# %%
data_pre = data_copy[['neighbourhood_group', 'room_type', 'price_log',
       'reviews_log', 'number_of_reviews_log', 'availability_365_log',
       'calculated_host_log']]
data_pre.head()
# Out:
#   neighbourhood_group        room_type  price_log  reviews_log  \
# 0            Brooklyn     Private room   5.003946    -1.560648
# 1           Manhattan  Entire home/apt   5.416100    -0.967584
# 2           Manhattan     Private room   5.010635    -0.693147
# 3            Brooklyn  Entire home/apt   4.488636     1.534714
# 4           Manhattan  Entire home/apt   4.382027    -2.302585
#
#    number_of_reviews_log  availability_365_log  calculated_host_log
# 0               2.302585              5.902633             1.945910
# 1               3.828641              5.874931             1.098612
# 2               0.000000              5.902633             0.693147
# 3               5.602119              5.273000             0.693147
# 4               2.302585              0.000000             0.693147

# %%
data_pre = pd.get_dummies(data_pre,columns=['neighbourhood_group','room_type'],drop_first=True)
data_pre.head()
# Out:
#    price_log  reviews_log  number_of_reviews_log  availability_365_log  \
# 0   5.003946    -1.560648               2.302585              5.902633
# 1   5.416100    -0.967584               3.828641              5.874931
# 2   5.010635    -0.693147               0.000000              5.902633
# 3   4.488636     1.534714               5.602119              5.273000
# 4   4.382027    -2.302585               2.302585              0.000000
#
#    calculated_host_log  neighbourhood_group_Brooklyn  \
# 0             1.945910                             1
# 1             1.098612                             0
# 2             0.693147                             0
# 3             0.693147                             1
# 4             0.693147                             0
#
#    neighbourhood_group_Manhattan  neighbourhood_group_Queens  \
# 0                              0                           0
# 1                              1                           0
# ...

# %%
X  =data_pre.drop(columns=['price_log'])
X.head()

y = data_pre['price_log']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns)
# Out:
#                                          vif
# reviews_log                         2.961529
# number_of_reviews_log              10.975131
# availability_365_log                4.251172
# calculated_host_log                 4.603213
# neighbourhood_group_Brooklyn        7.420135
# neighbourhood_group_Manhattan       7.149477
# neighbourhood_group_Queens          1.966468
# neighbourhood_group_Staten Island   1.098987
# room_type_Private room              1.683942
# room_type_Shared room               1.028795

# %%
X = data_pre.drop(columns=['price_log','number_of_reviews_log'])
X.head()
# Out:
#    reviews_log  availability_365_log  calculated_host_log  \
# 0    -1.560648              5.902633             1.945910
# 1    -0.967584              5.874931             1.098612
# 2    -0.693147              5.902633             0.693147
# 3     1.534714              5.273000             0.693147
# 4    -2.302585              0.000000             0.693147
#
#    neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# 0                             1                              0
# 1                             0                              1
# 2                             0                              1
# 3                             1                              0
# 4                             0                              1
#
#    neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# 0                           0                                  0
# 1                           0                                  0
# ...

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns)
# Out:
#                                         vif
# reviews_log                        1.557398
# availability_365_log               3.770906
# calculated_host_log                4.582330
# neighbourhood_group_Brooklyn       3.683486
# neighbourhood_group_Manhattan      3.344950
# neighbourhood_group_Queens         1.464542
# neighbourhood_group_Staten Island  1.058829
# room_type_Private room             1.683832
# room_type_Shared room              1.028659

# %%
X = data_pre.drop(columns=['price_log','number_of_reviews_log','calculated_host_log'])
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
pd.DataFrame({'vif':vif},index=X.columns)
# Out:
#                                         vif
# reviews_log                        1.541048
# availability_365_log               3.506913
# neighbourhood_group_Brooklyn       2.803629
# neighbourhood_group_Manhattan      2.653081
# neighbourhood_group_Queens         1.352884
# neighbourhood_group_Staten Island  1.043905
# room_type_Private room             1.669283
# room_type_Shared room              1.028469

# %%
import warnings 
warnings.filterwarnings('ignore')
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              price_log   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     298.7
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):               0.00
# Time:                        19:37:57   Log-Likelihood:                -3168.7
# No. Observations:                4019   AIC:                             6355.
# Df Residuals:                    4010   BIC:                             6412.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
import seaborn as sns
sns.distplot(lin_reg.resid)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
model = LinearRegression()
rfe = RFE(model, 7)
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True  True  True  True  True  True  True]
# [1 1 1 1 1 1 1]

# %%
X.columns
# Out:
# Index(['number_of_reviews_log', 'neighbourhood_group_Brooklyn',
#        'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens',
#        'neighbourhood_group_Staten Island', 'room_type_Private room',
#        'room_type_Shared room'],
#       dtype='object')

# %%
X = data_pre[['number_of_reviews_log','neighbourhood_group_Brooklyn',
       'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens',
       'neighbourhood_group_Staten Island', 'room_type_Private room',
       'room_type_Shared room']]

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.coef_
# Out:
# array([ 0.08753096, -0.10421209,  0.37167266,  0.61400253,  0.18513496,
#         0.25770483, -0.73252144, -0.89056161])

# %%
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              price_log   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     363.3
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):               0.00
# Time:                        20:26:40   Log-Likelihood:                -3121.3
# No. Observations:                4019   AIC:                             6259.
# Df Residuals:                    4011   BIC:                             6309.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
sns.distplot(lin_reg.resid)

# %%
reg = LassoCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# Best alpha using built-in LassoCV: 0.000840
# Best score using built-in LassoCV: 0.387000

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 5 variables and eliminated the other 2 variables

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %%
X = X.drop(columns=['neighbourhood_group_Queens','neighbourhood_group_Staten Island'])
X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              price_log   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     507.1
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):               0.00
# Time:                        20:28:35   Log-Likelihood:                -3124.0
# No. Observations:                4019   AIC:                             6260.
# Df Residuals:                    4013   BIC:                             6298.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
X_constant = sm.add_constant(X_train)
lin_reg = sm.OLS(y_train,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              price_log   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     339.2
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):          7.60e-285
# Time:                        20:30:42   Log-Likelihood:                -2243.4
# No. Observations:                2813   AIC:                             4499.
# Df Residuals:                    2807   BIC:                             4534.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.score(X_test,y_test)
# Out:
# 0.4121350772950958

# %%
model.score(X_train,y_train)
# Out:
# 0.3766374701020214
